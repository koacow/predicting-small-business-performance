# %% [markdown]
# # Compiling Yelp Restaurant Dataset
#
# ## Overview
#
# This notebook compiles a dataset of restaurants from Yelp business data. Then we will combine this with labor market/economic data from BLS and BEA to analyze what causes small business openings and closings.
#
# ## Getting Started
# 1. Download the required libraries:
#     ```bash
#     pip install -r requirements.txt
#     ```
#
# 2. Create the `data/` directory and place the downloaded data files in the appropriate subdirectories as specified in the sources section.
#     ```bash
#     cd predicting-labor-market-trends
#     mkdir data
#     mkdir data/bea
#     mkdir data/bls
#     ```
#
# ## Sources
#
# If API is not specified, data must be downloaded manually.
#
# - *Yelp Business Dataset*: https://business.yelp.com/data/resources/open-dataset/
# - *BLS LAUS*: https://www.bls.gov/lau/tables.htm#cntyaa (Download Labor force data by county, 2023 annual averages (XLSX))
# - *BEA CAGDP1*: https://apps.bea.gov/regional/downloadzip.htm (Download CAGDP1 folder under GDP tab)
# - *County Shapefiles*: https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_county_5m.zip
#
# ## Directory Structure
# ```bash
# predicting-small-business-performance/
#     ├── data/
#     │   ├── Yelp JSON/
#     │   │   └── yelp_dataset/
#     │   │       └── yelp_academic_dataset_business.json
#     │   │       └── yelp_academic_dataset_review.json
#     │   ├── bea/
#     │   │   └── CAGDP1__ALL_AREAS_2001_2023.csv
#     │   └── bls/
#     │       └── laucnty23.xlsx
#     │   └── cb_2018_us_county_5m/
#     │       └── cb_2018_us_county_5m.shp
#     │── compile_dataset.ipynb
#     └── business_economic_data.csv
# ```
#
# ## Data Dictionary
# | Column Name               | Data Type     | Description                                      | Source                     |
# |---------------------------|---------------|--------------------------------------------------|----------------------------|
# | FIPS5                    | String        | 5-digit FIPS code for the county where the business is located | BLS                        |
# | business_id               | String        | Unique identifier for each business              | Yelp                       |
# | is_open                  | Integer       | Indicates if the business is currently open (1) or closed (0) | Yelp                       |
# | stars                     | Float         | Average rating of the business                   | Yelp                       |
# | review_count              | Integer       | Number of reviews for the business               | Yelp                       |
# | attributes               | Object        | Various attributes of the business (e.g., "Good for Kids", "Outdoor Seating") | Yelp                       |
# | categories                | String        | Categories associated with the business          | Yelp                       |
# | name                      | String        | Name of the business                             | Yelp                       |
# | city                      | String        | City where the business is located               | Yelp                       |
# | state                     | String        | State where the business is located              | Yelp                       |
# | address                   | String        | Address of the business                          | Yelp                       |
# | postal_code               | String        | Postal code of the business                      | Yelp                       |
# | latitude                 | Float         | Latitude of the business location                | Yelp                       |
# | longitude                | Float         | Longitude of the business location               | Yelp                       |
# | geometry                 | Geometry      | GeoPandas geometry object for the business location, created from latitude and longitude | GeoPandas                       |
# | labor_force               | Integer       | Total labor force in the county                  | BLS                        |
# | employed                  | Integer       | Number of employed individuals in the county     | BLS                        |
# | unemployed                | Integer       | Number of unemployed individuals in the county   | BLS                        |
# | unemployment_rate        | Float         | Unemployment rate in the county                  | BLS                        |
# | gdp                       | Float         | Gross Domestic Product for the county            | BEA                        |

# %% [markdown]
# ## 1. Feature Engineering

# %%
import pandas as pd
import requests

YEAR = 2023

# %%
# 1. Loading BLS (Unemployment by County)
dtype = {
    'State FIPS Code': str,
    'County FIPS Code': str,
}

# Load each year's data and concatenate
BLS = pd.read_excel(f'./data/bls/laucnty{str(YEAR)[-2:]}.xlsx', skiprows=1, dtype=dtype)

# Create FIPS5 code - combination of State and County FIPS codes
BLS['FIPS5'] = BLS['State FIPS Code'] + BLS['County FIPS Code']

# Drop unnecessary columns and rows with missing FIPS5
BLS.drop(columns=['LAUS Code', 'County Name/State Abbreviation', 'State FIPS Code', 'County FIPS Code', 'Year'], inplace=True)
BLS.dropna(subset=['FIPS5'], inplace=True)

BLS
# Out:
#       Labor Force  Employed  Unemployed  Unemployment Rate (%)  FIPS5
# 0         27741.0   27150.0       591.0                    2.1  01001
# 1        113078.0  110639.0      2439.0                    2.2  01003
# 2          8660.0    8315.0       345.0                    4.0  01005
# 3          8582.0    8376.0       206.0                    2.4  01007
# 4         26501.0   25963.0       538.0                    2.0  01009
# ...           ...       ...         ...                    ...    ...
# 3216      18428.0   17344.0      1084.0                    5.9  72145
# 3217       2801.0    2689.0       112.0                    4.0  72147
# 3218       7250.0    6416.0       834.0                   11.5  72149
# 3219       9314.0    8548.0       766.0                    8.2  72151
# 3220      11614.0   10405.0      1209.0                   10.4  72153
#
# [3221 rows x 5 columns]

# %%
# 2. Loading BEA (Real GDP by County)
dtype = {
    'GeoFIPS': str,
}

# Load BEA data
BEA = pd.read_csv('./data/bea/CAGDP1__ALL_AREAS_2001_2023.csv', dtype=dtype, encoding='latin1', skipfooter=4)
BEA = BEA.rename(columns={'GeoFIPS': 'FIPS5'})

# Remove quotes and whitespace from FIPS5 codes
BEA['FIPS5'] = BEA['FIPS5'].str.replace('"', '').str.strip()

# Drop unnecessary columns
BEA = BEA.drop(columns=['GeoName', 'LineCode', 'Region', 'TableName', 'LineCode', 'IndustryClassification', 'Description', 'Unit'])

# Melt the DataFrame from wide to long format (initially each year is a separate column)
BEA = BEA.melt(id_vars=['FIPS5'], value_vars=[str(YEAR)], var_name='Year', value_name='GDP')
BEA = BEA[BEA['Year'] == str(YEAR)]
BEA.drop(columns=['Year'], inplace=True)

# Drop rows with missing FIPS5
BEA.dropna(subset=['FIPS5'], inplace=True)
BEA
# Out:
# /tmp/ipython-input-1326015454.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   BEA = pd.read_csv('./data/bea/CAGDP1__ALL_AREAS_2001_2023.csv', dtype=dtype, encoding='latin1', skipfooter=4)
#       FIPS5          GDP
# 0     00000  22671096000
# 1     00000      115.597
# 2     00000  27720709000
# 3     01000    245354674
# 4     01000      113.267
# ...     ...          ...
# 9529  97000      125.650
# 9530  97000   1057159025
# 9531  98000   4525827912
# 9532  98000      119.181
# 9533  98000   5421427913
#
# [9534 rows x 2 columns]

# %%
# 3. Merge Datasets into master panel
economic_df = pd.merge(BLS, BEA, on=['FIPS5'], how='left')
economic_df
# Out:
#       Labor Force  Employed  Unemployed  Unemployment Rate (%)  FIPS5      GDP
# 0         27741.0   27150.0       591.0                    2.1  01001  1945909
# 1         27741.0   27150.0       591.0                    2.1  01001  110.403
# 2         27741.0   27150.0       591.0                    2.1  01001  2452642
# 3        113078.0  110639.0      2439.0                    2.2  01003  9435720
# 4        113078.0  110639.0      2439.0                    2.2  01003  127.811
# ...           ...       ...         ...                    ...    ...      ...
# 9380      18428.0   17344.0      1084.0                    5.9  72145      NaN
# 9381       2801.0    2689.0       112.0                    4.0  72147      NaN
# 9382       7250.0    6416.0       834.0                   11.5  72149      NaN
# 9383       9314.0    8548.0       766.0                    8.2  72151      NaN
# 9384      11614.0   10405.0      1209.0                   10.4  72153      NaN
#
# [9385 rows x 6 columns]

# %%
print("Compiled dataset shape:", economic_df.shape)
print("Number of unique counties:", economic_df['FIPS5'].nunique())
# Out:
# Compiled dataset shape: (9385, 6)
# Number of unique counties: 3221

# %%
# 4. Descriptive statistics of relevant columns
vars = ['Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)', 'GDP']
economic_df[vars] = economic_df[vars].apply(pd.to_numeric, errors='coerce')
economic_df[vars].describe(include='all')
# Out:
#         Labor Force      Employed     Unemployed  Unemployment Rate (%)  \
# count  9.385000e+03  9.385000e+03    9385.000000            9385.000000
# mean   5.288523e+04  5.095182e+04    1933.410442               3.649579
# std    1.734801e+05  1.663361e+05    7351.499142               1.243862
# min    1.010000e+02  9.300000e+01       3.000000               1.300000
# 25%    4.630000e+03  4.481000e+03     170.000000               2.900000
# 50%    1.142900e+04  1.098500e+04     411.000000               3.500000
# 75%    3.180300e+04  3.072100e+04    1129.000000               4.200000
# max    5.055267e+06  4.799021e+06  256246.000000              17.600000
#
#                 GDP
# count  9.244000e+03
# mean   5.285505e+06
# std    2.893182e+07
# min    3.405100e+01
# 25%    1.188237e+02
# 50%    4.578975e+05
# 75%    1.935246e+06
# max    9.619081e+08

# %%
print("Missing data proportions:")
economic_df[vars].isna().sum() / len(economic_df)
# Out:
# Missing data proportions:
# Labor Force              0.000000
# Employed                 0.000000
# Unemployed               0.000000
# Unemployment Rate (%)    0.000000
# GDP                      0.015024
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
df = pd.read_json('./data/Yelp JSON/yelp_dataset/yelp_academic_dataset_business.json', lines=True)
df = df.dropna(subset=['is_open', 'latitude', 'longitude', 'stars', 'review_count', 'attributes', 'categories'])
min_class_count = df['is_open'].value_counts().min()
df = df.groupby('is_open').apply(lambda x: x.sample(min_class_count, random_state=42)).reset_index(drop=True)
df
# Out:
# /tmp/ipython-input-3417442114.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('is_open').apply(lambda x: x.sample(min_class_count, random_state=42)).reset_index(drop=True)
#                   business_id  \
# 0      XWIJOIHpFR1JrkOIYHILlg
# 1      RGTn5UPvZ84ScaaaaW2rxw
# 2      ELXPbZrMesEAlOp7LYUGAw
# 3      1rfNEXrSkGXSd8LG27ncMA
# 4      qKtkYb9lyQj_psgyg_wQlA
# ...                       ...
# 58499  e6sTyJUiEJCDmqrD86-xMw
# 58500  r5thRhSnNss1SabpD-varw
# 58501  6dXONUFQwVBEy5rjuqyatw
# 58502  ZFF_anxwMwoSn0o4GlRDOg
# 58503  uW8L6awmCyjovD9OhWPo7g
#
#                                                     name  \
# 0                             Chumley's Restaurant & Pub
# 1                                       Forza! Pasta Bar
# 2      The Village at Arrow Creek Parkway by Avenue5 ...
# 3                                Modell's Sporting Goods
# 4                            Francis The Duke Barber Co.
# ...                                                  ...
# 58499                             Schoenhouse and Manter
# 58500                                          Value Kia
# 58501                                         Small Mart
# 58502                    sweetFrog Premium Frozen Yogurt
# 58503                                         Casa Video
#
#                              address             city state postal_code  \
# 0                       1160 1st Ave  King of Prussia    PA       19406
# 1            664 Wye Road, Suite 190    Sherwood Park    AB     T8A 6B8
# 2                750 Arrowcreek Pkwy             Reno    NV       89511
# 3                   2329 Cottman Ave     Philadelphia    PA       19149
# 4               1001 N 2nd St, Ste 7     Philadelphia    PA       19123
# ...                              ...              ...   ...         ...
# 58499                2206 21st Ave S        Nashville    TN       37209
# 58500             6915 Essington Ave     Philadelphia    PA       19153
# 58501               2700 Chartres St      New Orleans    LA       70116
# 58502  175 Damonte Ranch Pkwy, Ste D             Reno    NV       89512
# 58503           2905 E Speedway Blvd           Tucson    AZ       85716
#
#         latitude   longitude  stars  review_count  is_open  \
# 0      40.096547  -75.415664    2.5             8        0
# 1      53.513143 -113.273791    4.0             6        0
# 2      39.410592 -119.758526    3.5            22        0
# 3      40.047979  -75.056021    3.5             8        0
# 4      39.966595  -75.140059    4.5            19        0
# ...          ...         ...    ...           ...      ...
# 58499  36.129583  -86.802048    5.0             8        1
# 58500  39.905522  -75.224934    1.5            43        1
# 58501  29.963508  -90.050725    4.5            80        1
# 58502  39.421931 -119.754476    2.5            21        1
# 58503  32.236435 -110.929217    4.5           151        1
#
#                                               attributes  \
# 0      {'Alcohol': ''full_bar'', 'OutdoorSeating': 'F...
# 1      {'NoiseLevel': ''quiet'', 'RestaurantsDelivery...
# 2      {'WheelchairAccessible': 'True', 'ByAppointmen...
# 3      {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 4      {'RestaurantsPriceRange2': '2', 'ByAppointment...
# ...                                                  ...
# 58499  {'BusinessAcceptsCreditCards': 'False', 'ByApp...
# 58500             {'BusinessAcceptsCreditCards': 'True'}
# 58501  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 58502  {'WiFi': 'u'free'', 'RestaurantsTakeOut': 'Tru...
# 58503  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                               categories  \
# 0      Restaurants, Nightlife, Hotels, Bars, Event Pl...
# 1                  Italian, Nightlife, Bars, Restaurants
# 2                 Home Services, Apartments, Real Estate
# 3                 Sporting Goods, Shopping, Local Flavor
# 4      Barbers, Men's Clothing, Beauty & Spas, Shoppi...
# ...                                                  ...
# 58499  Real Estate Agents, Home Services, Real Estate...
# 58500  Auto Parts & Supplies, Auto Repair, Car Dealer...
# 58501  Food, Grocery, Shopping, Bagels, Indian, Asian...
# 58502                    Food, Ice Cream & Frozen Yogurt
# 58503  Books, Mags, Music & Video, Shopping, Videos &...
#
#                                                    hours
# 0                                                   None
# 1      {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 2      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# 3      {'Monday': '9:0-21:30', 'Tuesday': '9:0-21:30'...
# 4      {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# ...                                                  ...
# 58499  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 58500  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 58501  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:30', ...
# 58502  {'Friday': '12:0-20:0', 'Saturday': '12:0-20:0...
# 58503  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
#
# [58504 rows x 14 columns]

# %%
import geopandas as gpd
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude), crs='EPSG:4326')

# %%
county_shapefile = gpd.read_file('./data/cb_2018_us_county_5m/cb_2018_us_county_5m.shp')
county_shapefile['FIPS5'] = county_shapefile['STATEFP'] + county_shapefile['COUNTYFP']
county_shapefile = county_shapefile.to_crs(epsg=4326)
county_shapefile = county_shapefile[['FIPS5', 'geometry']]
gdf = gpd.sjoin(gdf, county_shapefile, how='left', predicate='within')
gdf = gdf.drop(columns=['index_right'])
gdf
# Out:
#                   business_id  \
# 0      XWIJOIHpFR1JrkOIYHILlg
# 1      RGTn5UPvZ84ScaaaaW2rxw
# 2      ELXPbZrMesEAlOp7LYUGAw
# 3      1rfNEXrSkGXSd8LG27ncMA
# 4      qKtkYb9lyQj_psgyg_wQlA
# ...                       ...
# 58499  e6sTyJUiEJCDmqrD86-xMw
# 58500  r5thRhSnNss1SabpD-varw
# 58501  6dXONUFQwVBEy5rjuqyatw
# 58502  ZFF_anxwMwoSn0o4GlRDOg
# 58503  uW8L6awmCyjovD9OhWPo7g
#
#                                                     name  \
# 0                             Chumley's Restaurant & Pub
# 1                                       Forza! Pasta Bar
# 2      The Village at Arrow Creek Parkway by Avenue5 ...
# 3                                Modell's Sporting Goods
# 4                            Francis The Duke Barber Co.
# ...                                                  ...
# 58499                             Schoenhouse and Manter
# 58500                                          Value Kia
# 58501                                         Small Mart
# 58502                    sweetFrog Premium Frozen Yogurt
# 58503                                         Casa Video
#
#                              address             city state postal_code  \
# 0                       1160 1st Ave  King of Prussia    PA       19406
# 1            664 Wye Road, Suite 190    Sherwood Park    AB     T8A 6B8
# 2                750 Arrowcreek Pkwy             Reno    NV       89511
# 3                   2329 Cottman Ave     Philadelphia    PA       19149
# 4               1001 N 2nd St, Ste 7     Philadelphia    PA       19123
# ...                              ...              ...   ...         ...
# 58499                2206 21st Ave S        Nashville    TN       37209
# 58500             6915 Essington Ave     Philadelphia    PA       19153
# 58501               2700 Chartres St      New Orleans    LA       70116
# 58502  175 Damonte Ranch Pkwy, Ste D             Reno    NV       89512
# 58503           2905 E Speedway Blvd           Tucson    AZ       85716
#
#         latitude   longitude  stars  review_count  is_open  \
# 0      40.096547  -75.415664    2.5             8        0
# 1      53.513143 -113.273791    4.0             6        0
# 2      39.410592 -119.758526    3.5            22        0
# 3      40.047979  -75.056021    3.5             8        0
# 4      39.966595  -75.140059    4.5            19        0
# ...          ...         ...    ...           ...      ...
# 58499  36.129583  -86.802048    5.0             8        1
# 58500  39.905522  -75.224934    1.5            43        1
# 58501  29.963508  -90.050725    4.5            80        1
# 58502  39.421931 -119.754476    2.5            21        1
# 58503  32.236435 -110.929217    4.5           151        1
#
#                                               attributes  \
# 0      {'Alcohol': ''full_bar'', 'OutdoorSeating': 'F...
# 1      {'NoiseLevel': ''quiet'', 'RestaurantsDelivery...
# 2      {'WheelchairAccessible': 'True', 'ByAppointmen...
# 3      {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 4      {'RestaurantsPriceRange2': '2', 'ByAppointment...
# ...                                                  ...
# 58499  {'BusinessAcceptsCreditCards': 'False', 'ByApp...
# 58500             {'BusinessAcceptsCreditCards': 'True'}
# 58501  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 58502  {'WiFi': 'u'free'', 'RestaurantsTakeOut': 'Tru...
# 58503  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                               categories  \
# 0      Restaurants, Nightlife, Hotels, Bars, Event Pl...
# 1                  Italian, Nightlife, Bars, Restaurants
# 2                 Home Services, Apartments, Real Estate
# 3                 Sporting Goods, Shopping, Local Flavor
# 4      Barbers, Men's Clothing, Beauty & Spas, Shoppi...
# ...                                                  ...
# 58499  Real Estate Agents, Home Services, Real Estate...
# 58500  Auto Parts & Supplies, Auto Repair, Car Dealer...
# 58501  Food, Grocery, Shopping, Bagels, Indian, Asian...
# 58502                    Food, Ice Cream & Frozen Yogurt
# 58503  Books, Mags, Music & Video, Shopping, Videos &...
#
#                                                    hours  \
# 0                                                   None
# 1      {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 2      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# 3      {'Monday': '9:0-21:30', 'Tuesday': '9:0-21:30'...
# 4      {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# ...                                                  ...
# 58499  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 58500  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 58501  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:30', ...
# 58502  {'Friday': '12:0-20:0', 'Saturday': '12:0-20:0...
# 58503  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
#
#                           geometry  FIPS5
# 0       POINT (-75.41566 40.09655)  42091
# 1      POINT (-113.27379 53.51314)    NaN
# 2      POINT (-119.75853 39.41059)  32031
# 3       POINT (-75.05602 40.04798)  42101
# 4        POINT (-75.14006 39.9666)  42101
# ...                            ...    ...
# 58499   POINT (-86.80205 36.12958)  47037
# 58500   POINT (-75.22493 39.90552)  42101
# 58501   POINT (-90.05073 29.96351)  22071
# 58502  POINT (-119.75448 39.42193)  32031
# 58503  POINT (-110.92922 32.23643)  04019
#
# [58504 rows x 16 columns]

# %%
df = pd.merge(gdf, economic_df, on='FIPS5', how='left')
df = df.drop_duplicates(subset=['business_id'], keep='first')
df
# Out:
#                    business_id  \
# 0       XWIJOIHpFR1JrkOIYHILlg
# 3       RGTn5UPvZ84ScaaaaW2rxw
# 4       ELXPbZrMesEAlOp7LYUGAw
# 7       1rfNEXrSkGXSd8LG27ncMA
# 10      qKtkYb9lyQj_psgyg_wQlA
# ...                        ...
# 171103  e6sTyJUiEJCDmqrD86-xMw
# 171106  r5thRhSnNss1SabpD-varw
# 171109  6dXONUFQwVBEy5rjuqyatw
# 171112  ZFF_anxwMwoSn0o4GlRDOg
# 171115  uW8L6awmCyjovD9OhWPo7g
#
#                                                      name  \
# 0                              Chumley's Restaurant & Pub
# 3                                        Forza! Pasta Bar
# 4       The Village at Arrow Creek Parkway by Avenue5 ...
# 7                                 Modell's Sporting Goods
# 10                            Francis The Duke Barber Co.
# ...                                                   ...
# 171103                             Schoenhouse and Manter
# 171106                                          Value Kia
# 171109                                         Small Mart
# 171112                    sweetFrog Premium Frozen Yogurt
# 171115                                         Casa Video
#
#                               address             city state postal_code  \
# 0                        1160 1st Ave  King of Prussia    PA       19406
# 3             664 Wye Road, Suite 190    Sherwood Park    AB     T8A 6B8
# 4                 750 Arrowcreek Pkwy             Reno    NV       89511
# 7                    2329 Cottman Ave     Philadelphia    PA       19149
# 10               1001 N 2nd St, Ste 7     Philadelphia    PA       19123
# ...                               ...              ...   ...         ...
# 171103                2206 21st Ave S        Nashville    TN       37209
# 171106             6915 Essington Ave     Philadelphia    PA       19153
# 171109               2700 Chartres St      New Orleans    LA       70116
# 171112  175 Damonte Ranch Pkwy, Ste D             Reno    NV       89512
# 171115           2905 E Speedway Blvd           Tucson    AZ       85716
#
#          latitude   longitude  stars  review_count  ...  \
# 0       40.096547  -75.415664    2.5             8  ...
# 3       53.513143 -113.273791    4.0             6  ...
# 4       39.410592 -119.758526    3.5            22  ...
# 7       40.047979  -75.056021    3.5             8  ...
# 10      39.966595  -75.140059    4.5            19  ...
# ...           ...         ...    ...           ...  ...
# 171103  36.129583  -86.802048    5.0             8  ...
# 171106  39.905522  -75.224934    1.5            43  ...
# 171109  29.963508  -90.050725    4.5            80  ...
# 171112  39.421931 -119.754476    2.5            21  ...
# 171115  32.236435 -110.929217    4.5           151  ...
#
#                                                attributes  \
# 0       {'Alcohol': ''full_bar'', 'OutdoorSeating': 'F...
# 3       {'NoiseLevel': ''quiet'', 'RestaurantsDelivery...
# 4       {'WheelchairAccessible': 'True', 'ByAppointmen...
# 7       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 10      {'RestaurantsPriceRange2': '2', 'ByAppointment...
# ...                                                   ...
# 171103  {'BusinessAcceptsCreditCards': 'False', 'ByApp...
# 171106             {'BusinessAcceptsCreditCards': 'True'}
# 171109  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 171112  {'WiFi': 'u'free'', 'RestaurantsTakeOut': 'Tru...
# 171115  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                                categories  \
# 0       Restaurants, Nightlife, Hotels, Bars, Event Pl...
# 3                   Italian, Nightlife, Bars, Restaurants
# 4                  Home Services, Apartments, Real Estate
# 7                  Sporting Goods, Shopping, Local Flavor
# 10      Barbers, Men's Clothing, Beauty & Spas, Shoppi...
# ...                                                   ...
# 171103  Real Estate Agents, Home Services, Real Estate...
# 171106  Auto Parts & Supplies, Auto Repair, Car Dealer...
# 171109  Food, Grocery, Shopping, Bagels, Indian, Asian...
# 171112                    Food, Ice Cream & Frozen Yogurt
# 171115  Books, Mags, Music & Video, Shopping, Videos &...
#
#                                                     hours  \
# 0                                                    None
# 3       {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 4       {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# 7       {'Monday': '9:0-21:30', 'Tuesday': '9:0-21:30'...
# 10      {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# ...                                                   ...
# 171103  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 171106  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 171109  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:30', ...
# 171112  {'Friday': '12:0-20:0', 'Saturday': '12:0-20:0...
# 171115  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
#
#                            geometry  FIPS5 Labor Force  Employed  Unemployed  \
# 0        POINT (-75.41566 40.09655)  42091    474525.0  460242.0     14283.0
# 3       POINT (-113.27379 53.51314)    NaN         NaN       NaN         NaN
# 4       POINT (-119.75853 39.41059)  32031    264836.0  253239.0     11597.0
# 7        POINT (-75.05602 40.04798)  42101    781326.0  747594.0     33732.0
# 10        POINT (-75.14006 39.9666)  42101    781326.0  747594.0     33732.0
# ...                             ...    ...         ...       ...         ...
# 171103   POINT (-86.80205 36.12958)  47037    410190.0  399310.0     10880.0
# 171106   POINT (-75.22493 39.90552)  42101    781326.0  747594.0     33732.0
# 171109   POINT (-90.05073 29.96351)  22071    176980.0  169234.0      7746.0
# 171112  POINT (-119.75448 39.42193)  32031    264836.0  253239.0     11597.0
# 171115  POINT (-110.92922 32.23643)  04019    493940.0  476120.0     17820.0
#
#         Unemployment Rate (%)          GDP
# 0                         3.0   89401864.0
# 3                         NaN          NaN
# 4                         4.4   32124910.0
# 7                         4.3  110703184.0
# 10                        4.3  110703184.0
# ...                       ...          ...
# 171103                    2.7   87529092.0
# 171106                    4.3  110703184.0
# 171109                    4.4   23805024.0
# 171112                    4.4   32124910.0
# 171115                    3.6   50781363.0
#
# [58504 rows x 21 columns]

# %%
df = df.rename(columns={
    'Labor Force': 'labor_force',
    'Employed': 'employed',
    'Unemployed': 'unemployed',
    'Unemployment Rate (%)': 'unemployment_rate',
    'GDP': 'gdp',
})
df = df.drop(columns=['name', 'address', 'city', 'state', 'postal_code', 'latitude', 'longitude', 'geometry', 'FIPS5'])
df.dropna(subset=['labor_force', 'employed', 'unemployed', 'unemployment_rate', 'gdp'], inplace=True)
df
# Out:
#                    business_id  stars  review_count  is_open  \
# 0       XWIJOIHpFR1JrkOIYHILlg    2.5             8        0
# 4       ELXPbZrMesEAlOp7LYUGAw    3.5            22        0
# 7       1rfNEXrSkGXSd8LG27ncMA    3.5             8        0
# 10      qKtkYb9lyQj_psgyg_wQlA    4.5            19        0
# 13      KLBWUdr0nrrK2mPBj0qg_A    4.5            56        0
# ...                        ...    ...           ...      ...
# 171103  e6sTyJUiEJCDmqrD86-xMw    5.0             8        1
# 171106  r5thRhSnNss1SabpD-varw    1.5            43        1
# 171109  6dXONUFQwVBEy5rjuqyatw    4.5            80        1
# 171112  ZFF_anxwMwoSn0o4GlRDOg    2.5            21        1
# 171115  uW8L6awmCyjovD9OhWPo7g    4.5           151        1
#
#                                                attributes  \
# 0       {'Alcohol': ''full_bar'', 'OutdoorSeating': 'F...
# 4       {'WheelchairAccessible': 'True', 'ByAppointmen...
# 7       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 10      {'RestaurantsPriceRange2': '2', 'ByAppointment...
# 13      {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# ...                                                   ...
# 171103  {'BusinessAcceptsCreditCards': 'False', 'ByApp...
# 171106             {'BusinessAcceptsCreditCards': 'True'}
# 171109  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 171112  {'WiFi': 'u'free'', 'RestaurantsTakeOut': 'Tru...
# 171115  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                                categories  \
# 0       Restaurants, Nightlife, Hotels, Bars, Event Pl...
# 4                  Home Services, Apartments, Real Estate
# 7                  Sporting Goods, Shopping, Local Flavor
# 10      Barbers, Men's Clothing, Beauty & Spas, Shoppi...
# 13      Restaurants, Bubble Tea, Patisserie/Cake Shop,...
# ...                                                   ...
# 171103  Real Estate Agents, Home Services, Real Estate...
# 171106  Auto Parts & Supplies, Auto Repair, Car Dealer...
# 171109  Food, Grocery, Shopping, Bagels, Indian, Asian...
# 171112                    Food, Ice Cream & Frozen Yogurt
# 171115  Books, Mags, Music & Video, Shopping, Videos &...
#
#                                                     hours  labor_force  \
# 0                                                    None     474525.0
# 4       {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...     264836.0
# 7       {'Monday': '9:0-21:30', 'Tuesday': '9:0-21:30'...     781326.0
# 10      {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...     781326.0
# 13                                  {'Monday': '0:0-0:0'}     208399.0
# ...                                                   ...          ...
# 171103  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...     410190.0
# 171106  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...     781326.0
# 171109  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:30', ...     176980.0
# 171112  {'Friday': '12:0-20:0', 'Saturday': '12:0-20:0...     264836.0
# 171115  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...     493940.0
#
#         employed  unemployed  unemployment_rate          gdp
# 0       460242.0     14283.0                3.0   89401864.0
# 4       253239.0     11597.0                4.4   32124910.0
# 7       747594.0     33732.0                4.3  110703184.0
# 10      747594.0     33732.0                4.3  110703184.0
# 13      201167.0      7232.0                3.5   24410200.0
# ...          ...         ...                ...          ...
# 171103  399310.0     10880.0                2.7   87529092.0
# 171106  747594.0     33732.0                4.3  110703184.0
# 171109  169234.0      7746.0                4.4   23805024.0
# 171112  253239.0     11597.0                4.4   32124910.0
# 171115  476120.0     17820.0                3.6   50781363.0
#
# [56307 rows x 12 columns]

# %%
df['num_categories'] = df['categories'].apply(lambda x: len(x.split(', ')) if pd.notnull(x) else 0)

df['num_attributes'] = df['attributes'].apply(lambda x: len(x) if isinstance(x, dict) else 0)

def parse_hours(hours):
    total_hours = 0
    if isinstance(hours, dict):
        for day, time_range in hours.items():
            try:
                open_time, close_time = time_range.split('-')
                open_hour = int(open_time.split(':')[0])
                close_hour = int(close_time.split(':')[0])
                if close_hour < open_hour:
                    close_hour += 24
                total_hours += close_hour - open_hour
            except:
                continue
    else:
        total_hours = 0
    return total_hours

df['total_weekly_hours'] = df['hours'].apply(parse_hours)
df = df.drop(columns=['categories', 'attributes', 'hours'])
df
# Out:
#                    business_id  stars  review_count  is_open  labor_force  \
# 0       XWIJOIHpFR1JrkOIYHILlg    2.5             8        0     474525.0
# 4       ELXPbZrMesEAlOp7LYUGAw    3.5            22        0     264836.0
# 7       1rfNEXrSkGXSd8LG27ncMA    3.5             8        0     781326.0
# 10      qKtkYb9lyQj_psgyg_wQlA    4.5            19        0     781326.0
# 13      KLBWUdr0nrrK2mPBj0qg_A    4.5            56        0     208399.0
# ...                        ...    ...           ...      ...          ...
# 171103  e6sTyJUiEJCDmqrD86-xMw    5.0             8        1     410190.0
# 171106  r5thRhSnNss1SabpD-varw    1.5            43        1     781326.0
# 171109  6dXONUFQwVBEy5rjuqyatw    4.5            80        1     176980.0
# 171112  ZFF_anxwMwoSn0o4GlRDOg    2.5            21        1     264836.0
# 171115  uW8L6awmCyjovD9OhWPo7g    4.5           151        1     493940.0
#
#         employed  unemployed  unemployment_rate          gdp  num_categories  \
# 0       460242.0     14283.0                3.0   89401864.0               7
# 4       253239.0     11597.0                4.4   32124910.0               3
# 7       747594.0     33732.0                4.3  110703184.0               3
# 10      747594.0     33732.0                4.3  110703184.0               5
# 13      201167.0      7232.0                3.5   24410200.0               9
# ...          ...         ...                ...          ...             ...
# 171103  399310.0     10880.0                2.7   87529092.0               4
# 171106  747594.0     33732.0                4.3  110703184.0               4
# 171109  169234.0      7746.0                4.4   23805024.0               8
# 171112  253239.0     11597.0                4.4   32124910.0               2
# 171115  476120.0     17820.0                3.6   50781363.0               5
#
#         num_attributes  total_weekly_hours
# 0                    8                   0
# 4                    3                  59
# 7                    4                  81
# 10                   5                  58
# 13                  19                   0
# ...                ...                 ...
# 171103               2                  73
# 171106               1                  70
# 171109               6                  51
# 171112              10                  24
# 171115               5                 105
#
# [56307 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json
import gzip

# Define the path to the gzipped JSONL file
file_path = '/content/drive/MyDrive/yelp_academic_dataset_review.json.gz'

# List to store selected review data
review_data = []

# Open the gzipped file and read line by line
with gzip.open(file_path, 'rt', encoding='utf-8') as f:
    for line in f:
        try:
            # Parse each line as a JSON object
            review = json.loads(line)
            # Extract only the necessary columns
            review_data.append({
                'business_id': review['business_id'],
                'stars': review['stars'],
                'useful': review['useful'],
                'text': review['text']
            })
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e} in line: {line.strip()}")
            continue

# Create a DataFrame from the extracted data
reviews = pd.DataFrame(review_data)

# %%
# TODO: Attach reviews data (concatenate all reviews per business into a single text field), include weighted average star rating (by review usefulness)

# The 'reviews' DataFrame is already loaded from rLF2iBhFzxG8 with the necessary columns.
# The following line is redundant and causes error on re-execution:
# reviews = reviews[['business_id', 'stars', 'useful', 'text']]

# Aggregate reviews and store in a new variable to avoid overwriting the original 'reviews' DataFrame
aggregated_reviews = reviews.groupby('business_id').apply(lambda x: pd.Series({
    'weighted_avg_stars': (x['stars'] * x['useful']).sum() / x['useful'].sum() if x['useful'].sum() > 0 else x['stars'].mean(),
    'all_reviews_text': ' '.join(x['text'])
}), include_groups=False).reset_index()

df = pd.merge(df, aggregated_reviews, on='business_id', how='left')
# 'reviews' can be deleted here if no longer needed, or kept for other processing
del reviews
df
# Out:
# /tmp/ipython-input-318854071.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated_reviews = reviews.groupby('business_id').apply(lambda x: pd.Series({
#                   business_id  stars  review_count  is_open  labor_force  \
# 0      XWIJOIHpFR1JrkOIYHILlg    2.5             8        0     474525.0
# 1      ELXPbZrMesEAlOp7LYUGAw    3.5            22        0     264836.0
# 2      1rfNEXrSkGXSd8LG27ncMA    3.5             8        0     781326.0
# 3      qKtkYb9lyQj_psgyg_wQlA    4.5            19        0     781326.0
# 4      KLBWUdr0nrrK2mPBj0qg_A    4.5            56        0     208399.0
# ...                       ...    ...           ...      ...          ...
# 56302  e6sTyJUiEJCDmqrD86-xMw    5.0             8        1     410190.0
# 56303  r5thRhSnNss1SabpD-varw    1.5            43        1     781326.0
# 56304  6dXONUFQwVBEy5rjuqyatw    4.5            80        1     176980.0
# 56305  ZFF_anxwMwoSn0o4GlRDOg    2.5            21        1     264836.0
# 56306  uW8L6awmCyjovD9OhWPo7g    4.5           151        1     493940.0
#
#        employed  unemployed  unemployment_rate          gdp  num_categories  \
# 0      460242.0     14283.0                3.0   89401864.0               7
# 1      253239.0     11597.0                4.4   32124910.0               3
# 2      747594.0     33732.0                4.3  110703184.0               3
# 3      747594.0     33732.0                4.3  110703184.0               5
# 4      201167.0      7232.0                3.5   24410200.0               9
# ...         ...         ...                ...          ...             ...
# 56302  399310.0     10880.0                2.7   87529092.0               4
# 56303  747594.0     33732.0                4.3  110703184.0               4
# 56304  169234.0      7746.0                4.4   23805024.0               8
# 56305  253239.0     11597.0                4.4   32124910.0               2
# 56306  476120.0     17820.0                3.6   50781363.0               5
#
#        num_attributes  total_weekly_hours  weighted_avg_stars  \
# 0                   8                   0            2.000000
# 1                   3                  59            2.010101
# 2                   4                  81            2.250000
# 3                   5                  58            3.571429
# 4                  19                   0            4.586207
# ...               ...                 ...                 ...
# 56302               2                  73            5.000000
# 56303               1                  70            1.061995
# 56304               6                  51            4.411215
# 56305              10                  24            2.130435
# 56306               5                 105            4.435484
#
#                                         all_reviews_text
# 0      Only pub menu was available as they were revam...
# 1      We live here now. The apartment is almost perf...
# 2      This review is being posted in direct response...
# 3      After years of getting cheap and simple buzz j...
# 4      WORST CUSTOMER SERVICE! As we walked in, no on...
# ...                                                  ...
# 56302  Lisa and Miles make the perfect dynamic duo! T...
# 56303  After having car towed to Kia, car sits on lot...
# 56304  I just returned to Chicago from a 14-day road ...
# 56305  This frozen yogurt place is the best in Reno! ...
# 56306  As far as I know, this is the best video renta...
#
# [56307 rows x 14 columns]

# %%
tips = pd.read_json('./data/Yelp JSON/yelp_dataset/yelp_academic_dataset_tip.json', lines=True)
tips = tips[['business_id', 'text']]
tips = tips.groupby('business_id').apply(lambda x: ' '.join(x['text'])).reset_index()
tips = tips.rename(columns={0: 'tips'})
df = pd.merge(df, tips, on='business_id', how='left')
df['tips'] = df['tips'].fillna('')
del tips
df
# Out:
# /var/folders/zx/x6hb1_p95p33hh3235qrnlqm0000gn/T/ipykernel_25526/3937895968.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips = tips.groupby('business_id').apply(lambda x: ' '.join(x['text'])).reset_index()
#                   business_id  stars  review_count  is_open  labor_force  \
# 0      XWIJOIHpFR1JrkOIYHILlg    2.5             8        0     474525.0
# 1      ELXPbZrMesEAlOp7LYUGAw    3.5            22        0     264836.0
# 2      1rfNEXrSkGXSd8LG27ncMA    3.5             8        0     781326.0
# 3      qKtkYb9lyQj_psgyg_wQlA    4.5            19        0     781326.0
# 4      KLBWUdr0nrrK2mPBj0qg_A    4.5            56        0     208399.0
# ...                       ...    ...           ...      ...          ...
# 56302  e6sTyJUiEJCDmqrD86-xMw    5.0             8        1     410190.0
# 56303  r5thRhSnNss1SabpD-varw    1.5            43        1     781326.0
# 56304  6dXONUFQwVBEy5rjuqyatw    4.5            80        1     176980.0
# 56305  ZFF_anxwMwoSn0o4GlRDOg    2.5            21        1     264836.0
# 56306  uW8L6awmCyjovD9OhWPo7g    4.5           151        1     493940.0
#
#        employed  unemployed  unemployment_rate          gdp  num_categories  \
# 0      460242.0     14283.0                3.0   89401864.0               7
# 1      253239.0     11597.0                4.4   32124910.0               3
# 2      747594.0     33732.0                4.3  110703184.0               3
# 3      747594.0     33732.0                4.3  110703184.0               5
# 4      201167.0      7232.0                3.5   24410200.0               9
# ...         ...         ...                ...          ...             ...
# 56302  399310.0     10880.0                2.7   87529092.0               4
# 56303  747594.0     33732.0                4.3  110703184.0               4
# 56304  169234.0      7746.0                4.4   23805024.0               8
# 56305  253239.0     11597.0                4.4   32124910.0               2
# 56306  476120.0     17820.0                3.6   50781363.0               5
#
#        num_attributes  total_weekly_hours  \
# 0                   8                   0
# 1                   3                  59
# 2                   4                  81
# 3                   5                  58
# 4                  19                   0
# ...               ...                 ...
# 56302               2                  73
# 56303               1                  70
# 56304               6                  51
# 56305              10                  24
# 56306               5                 105
#
#                                                     tips
# 0
# 1
# 2      Looking for Phillies stuff Remember when this ...
# 3      Loving the executive shave! Will is the king o...
# 4                                          Good egg tart
# ...                                                  ...
# 56302
# 56303  Won't be going back Waste of several hours of ...
# 56304  This place has banana foster rootbeer! Bagels ...
# 56305
# 56306  Nothing like the video store & free popcorn! F...
#
# [56307 rows x 13 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
def analyze_sentiment(text):
    scores = analyzer.polarity_scores(text)
    return scores['compound']
df['tips_sentiment'] = df['tips'].apply(analyze_sentiment)
df
# Out:
#                   business_id  stars  review_count  is_open  labor_force  \
# 0      XWIJOIHpFR1JrkOIYHILlg    2.5             8        0     474525.0
# 1      ELXPbZrMesEAlOp7LYUGAw    3.5            22        0     264836.0
# 2      1rfNEXrSkGXSd8LG27ncMA    3.5             8        0     781326.0
# 3      qKtkYb9lyQj_psgyg_wQlA    4.5            19        0     781326.0
# 4      KLBWUdr0nrrK2mPBj0qg_A    4.5            56        0     208399.0
# ...                       ...    ...           ...      ...          ...
# 56302  e6sTyJUiEJCDmqrD86-xMw    5.0             8        1     410190.0
# 56303  r5thRhSnNss1SabpD-varw    1.5            43        1     781326.0
# 56304  6dXONUFQwVBEy5rjuqyatw    4.5            80        1     176980.0
# 56305  ZFF_anxwMwoSn0o4GlRDOg    2.5            21        1     264836.0
# 56306  uW8L6awmCyjovD9OhWPo7g    4.5           151        1     493940.0
#
#        employed  unemployed  unemployment_rate          gdp  num_categories  \
# 0      460242.0     14283.0                3.0   89401864.0               7
# 1      253239.0     11597.0                4.4   32124910.0               3
# 2      747594.0     33732.0                4.3  110703184.0               3
# 3      747594.0     33732.0                4.3  110703184.0               5
# 4      201167.0      7232.0                3.5   24410200.0               9
# ...         ...         ...                ...          ...             ...
# 56302  399310.0     10880.0                2.7   87529092.0               4
# 56303  747594.0     33732.0                4.3  110703184.0               4
# 56304  169234.0      7746.0                4.4   23805024.0               8
# 56305  253239.0     11597.0                4.4   32124910.0               2
# 56306  476120.0     17820.0                3.6   50781363.0               5
#
#        num_attributes  total_weekly_hours  \
# 0                   8                   0
# 1                   3                  59
# 2                   4                  81
# 3                   5                  58
# 4                  19                   0
# ...               ...                 ...
# 56302               2                  73
# 56303               1                  70
# 56304               6                  51
# 56305              10                  24
# 56306               5                 105
#
#                                                     tips  tips_sentiment
# 0                                                                 0.0000
# 1                                                                 0.0000
# 2      Looking for Phillies stuff Remember when this ...          0.0000
# 3      Loving the executive shave! Will is the king o...          0.9499
# 4                                          Good egg tart          0.4404
# ...                                                  ...             ...
# 56302                                                             0.0000
# 56303  Won't be going back Waste of several hours of ...         -0.9519
# 56304  This place has banana foster rootbeer! Bagels ...          0.9937
# 56305                                                             0.0000
# 56306  Nothing like the video store & free popcorn! F...          0.9865
#
# [56307 rows x 14 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns=['is_open', 'business_id']),
    df['is_open'],
    test_size=0.2,
    random_state=42,
    stratify=df['is_open']
)

X_train, y_train
# Out:
# (       stars  review_count  labor_force  employed  unemployed  \
#  5150     3.0            54     410190.0  399310.0     10880.0
#  2162     3.0            31     781326.0  747594.0     33732.0
#  18153    4.5            61     293302.0  283988.0      9314.0
#  20918    4.0            24     264836.0  253239.0     11597.0
#  46694    2.0            30     302961.0  292591.0     10370.0
#  ...      ...           ...          ...       ...         ...
#  27115    4.5             8     138392.0  134859.0      3533.0
#  20188    4.0            14     305681.0  294177.0     11504.0
#  27349    4.0             6     781326.0  747594.0     33732.0
#  34835    5.0             5     507381.0  493316.0     14065.0
#  27662    3.0            18     781326.0  747594.0     33732.0
#
#         unemployment_rate          gdp  num_categories  num_attributes  \
#  5150                 2.7   87529092.0               2               1
#  2162                 4.3  110703184.0               7              17
#  18153                3.2   17659216.0               3              18
#  20918                4.4   32124910.0               3              19
#  46694                3.4   34713305.0               4               1
#  ...                  ...          ...             ...             ...
#  27115                2.6   30283015.0               2               3
#  20188                3.8   54376189.0               3              18
#  27349                4.3  110703184.0               3               2
#  34835                2.8   60134522.0               8               3
#  27662                4.3  110703184.0               4              15
#
#         total_weekly_hours                                               tips  \
#  5150                   66  Interior detail - $59.95. Lack of Chico and Be...
#  2162                   68  Where the heck was everyone at 10 pm on a Satu...
#  18153                  48  Food is very good and prices are very reasonab...
#  20918                  79  Parking lot can be accessed from Valley or Den...
#  46694                  65  Yesterday I came in for an inspection and need...
#  ...                   ...                                                ...
#  27115                  72
#  20188                  50  Not much to look at but their hoagies, please ...
#  27349                  54  New # is 215-954-1935! Moving From Current Loc...
#  34835                  40  Only place to go, if you really desire to get ...
#  27662                  78  Decent lunch specials Best hand drawn noodles ...
#
#         tips_sentiment
#  5150           0.9812
#  2162          -0.5095
#  18153          0.9803
#  20918          0.9030
#  46694         -0.8221
#  ...               ...
#  27115          0.0000
#  20188          0.8765
#  27349          0.0000
#  34835          0.7264
#  27662          0.9686
#
#  [45045 rows x 12 columns],
#  5150     0
#  2162     0
#  18153    0
#  20918    0
#  46694    1
#          ..
#  27115    0
#  20188    0
#  27349    0
#  34835    1
#  27662    0
#  Name: is_open, Length: 45045, dtype: int64)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    max_features=5000,
    min_df=5,
    max_df=0.8,
    strip_accents='unicode',
    lowercase=True,
    token_pattern=r'\b[a-zA-Z]{2,}\b'
)
tfidf.fit(df['tips'])

X_train_tfidf = pd.DataFrame(tfidf.transform(X_train['tips']).toarray(), index=X_train.index, columns=tfidf.get_feature_names_out())
X_test_tfidf = pd.DataFrame(tfidf.transform(X_test['tips']).toarray(), index=X_test.index, columns=tfidf.get_feature_names_out())

X_train = pd.concat([X_train.drop(columns=['tips']), X_train_tfidf], axis=1)
X_test = pd.concat([X_test.drop(columns=['tips']), X_test_tfidf], axis=1)
X_train
# Out:
#        stars  review_count  labor_force  employed  unemployed  \
# 5150     3.0            54     410190.0  399310.0     10880.0
# 2162     3.0            31     781326.0  747594.0     33732.0
# 18153    4.5            61     293302.0  283988.0      9314.0
# 20918    4.0            24     264836.0  253239.0     11597.0
# 46694    2.0            30     302961.0  292591.0     10370.0
# ...      ...           ...          ...       ...         ...
# 27115    4.5             8     138392.0  134859.0      3533.0
# 20188    4.0            14     305681.0  294177.0     11504.0
# 27349    4.0             6     781326.0  747594.0     33732.0
# 34835    5.0             5     507381.0  493316.0     14065.0
# 27662    3.0            18     781326.0  747594.0     33732.0
#
#        unemployment_rate          gdp  num_categories  num_attributes  \
# 5150                 2.7   87529092.0               2               1
# 2162                 4.3  110703184.0               7              17
# 18153                3.2   17659216.0               3              18
# 20918                4.4   32124910.0               3              19
# 46694                3.4   34713305.0               4               1
# ...                  ...          ...             ...             ...
# 27115                2.6   30283015.0               2               3
# 20188                3.8   54376189.0               3              18
# 27349                4.3  110703184.0               3               2
# 34835                2.8   60134522.0               8               3
# 27662                4.3  110703184.0               4              15
#
#        total_weekly_hours  ...  yuck       yum  yum great  yum the  yum yum  \
# 5150                   66  ...   0.0  0.000000        0.0      0.0      0.0
# 2162                   68  ...   0.0  0.000000        0.0      0.0      0.0
# 18153                  48  ...   0.0  0.097776        0.0      0.0      0.0
# 20918                  79  ...   0.0  0.000000        0.0      0.0      0.0
# 46694                  65  ...   0.0  0.000000        0.0      0.0      0.0
# ...                   ...  ...   ...       ...        ...      ...      ...
# 27115                  72  ...   0.0  0.000000        0.0      0.0      0.0
# 20188                  50  ...   0.0  0.000000        0.0      0.0      0.0
# 27349                  54  ...   0.0  0.000000        0.0      0.0      0.0
# 34835                  40  ...   0.0  0.000000        0.0      0.0      0.0
# 27662                  78  ...   0.0  0.000000        0.0      0.0      0.0
#
#        yumm     yummy  yummy and  yummy food  zero
# 5150    0.0  0.000000        0.0         0.0   0.0
# 2162    0.0  0.000000        0.0         0.0   0.0
# 18153   0.0  0.090766        0.0         0.0   0.0
# 20918   0.0  0.125741        0.0         0.0   0.0
# 46694   0.0  0.000000        0.0         0.0   0.0
# ...     ...       ...        ...         ...   ...
# 27115   0.0  0.000000        0.0         0.0   0.0
# 20188   0.0  0.000000        0.0         0.0   0.0
# 27349   0.0  0.000000        0.0         0.0   0.0
# 34835   0.0  0.000000        0.0         0.0   0.0
# 27662   0.0  0.000000        0.0         0.0   0.0
#
# [45045 rows x 5011 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-0.64483236,  0.08059467, -0.09144489, ..., -0.0475061 ,
#         -0.05337614, -0.0374316 ],
#        [-0.64483236, -0.12808632,  1.61324376, ..., -0.0475061 ,
#         -0.05337614, -0.0374316 ],
#        [ 0.98898073,  0.14410627, -0.62833069, ..., -0.0475061 ,
#         -0.05337614, -0.0374316 ],
#        ...,
#        [ 0.44437637, -0.35491348,  1.61324376, ..., -0.0475061 ,
#         -0.05337614, -0.0374316 ],
#        [ 1.5335851 , -0.36398657,  0.35496935, ..., -0.0475061 ,
#         -0.05337614, -0.0374316 ],
#        [-0.64483236, -0.24603644,  1.61324376, ..., -0.0475061 ,
#         -0.05337614, -0.0374316 ]], shape=(45045, 5011))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix

base_model = LogisticRegression(max_iter=1000, random_state=42)
model = BaggingClassifier(estimator=base_model, n_estimators=10, random_state=42)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.62      0.65      5614
#            1       0.65      0.72      0.69      5648
#
#     accuracy                           0.67     11262
#    macro avg       0.67      0.67      0.67     11262
# weighted avg       0.67      0.67      0.67     11262

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[3473, 2141],
#        [1587, 4061]])
